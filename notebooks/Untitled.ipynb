# %%
import pandas as pd
from quickplot import QuickPlot

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_pickle('../data/processed/series1.pkl')

# %%
plt.switch_backend('Qt5Agg')

# %%
with QuickPlot() as qp:
    qp.plot(data.set_index('time'))
